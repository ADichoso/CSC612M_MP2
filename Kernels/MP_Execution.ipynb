# %%
import os

# Add the directory containing the executable to the PATH
os.environ["PATH"] += os.pathsep + "/usr/local/cuda/bin"

# Check if the directory is added to the PATH
print(os.environ["PATH"])
# Out:
# /opt/tljh/user/bin:/bin:/usr/bin:/usr/local/cuda/bin

# %%
# %%bash
# nvcc --version
# nvprof --version
# nsys --version
# ncu --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2025 NVIDIA Corporation
# Built on Wed_Apr__9_19:24:57_PDT_2025
# Cuda compilation tools, release 12.9, V12.9.41
# Build cuda_12.9.r12.9/compiler.35813241_0
# nvprof: NVIDIA (R) Cuda command line profiler
# Copyright (c) 2012 - 2025 NVIDIA Corporation
# Release version 12.9.19 (21)
# NVIDIA Nsight Systems version 2025.1.3.140-251335620677v0
# NVIDIA (R) Nsight Compute Command Line Profiler
# Copyright (c) 2018-2025 NVIDIA Corporation
# Version 2025.2.0.0 (build 35613519) (public-release)

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sat Nov 22 05:49:35 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 575.51.03              Driver Version: 575.51.03      CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla V100-PCIE-32GB           Off |   00000000:00:10.0 Off |                    0 |
# | N/A   28C    P0             22W /  250W |       0MiB /  32768MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# # CUDA Execution - 4 Dimensions

# %%
# %%bash
# nvcc CUDA_cpso_4_sphere.cu -o CUDA_cpso_4_sphere --expt-relaxed-constexpr -arch=sm_70 -Wno-deprecated-gpu-targets

# %%
# %%bash
# nvcc CUDA_cpso_4_ackley.cu -o CUDA_cpso_4_ackley --expt-relaxed-constexpr -arch=sm_70 -Wno-deprecated-gpu-targets

# %%
# %%bash
# nvcc CUDA_cpso_4_rosenbrock.cu -o CUDA_cpso_4_rosenbrock --expt-relaxed-constexpr -arch=sm_70 -Wno-deprecated-gpu-targets

# %%
# %%bash
# nvprof ./CUDA_cpso_4_sphere
# Out:
# ==142408== NVPROF is profiling process 142408, command: ./CUDA_cpso_4_sphere
# ==142408== Profiling application: ./CUDA_cpso_4_sphere
# ==142408== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   99.71%  5.26255s     15000  350.84us  97.247us  6.7418ms  particleAction(Swarm*, unsigned long, int, double*, int, int, double (*) (unsigned long, double*, double, unsigned long))
#                     0.29%  15.330ms        30  510.99us  243.78us  880.57us  [CUDA memset]
#                     0.00%  2.2720us         1  2.2720us  2.2720us  2.2720us  [CUDA memcpy DtoH]
#       API calls:   57.98%  9.84225s     15090  652.24us  2.8330us  10.604ms  cudaDeviceSynchronize
#                    25.79%  4.37877s     30330  144.37us  12.501us  2.4247ms  cudaMemPrefetchAsync
#                    10.09%  1.71207s     15000  114.14us  15.531us  2.4192ms  cudaLaunchKernel
# ...

# %%
# %%bash
# nvprof ./CUDA_cpso_4_ackley
# Out:
# ==142449== NVPROF is profiling process 142449, command: ./CUDA_cpso_4_ackley
# ==142449== Profiling application: ./CUDA_cpso_4_ackley
# ==142449== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   99.68%  5.16031s     15000  344.02us  81.664us  5.3125ms  particleAction(Swarm*, unsigned long, int, double*, int, int, double (*) (unsigned long, double*, double, unsigned long))
#                     0.32%  16.330ms        30  544.33us  306.43us  1.2199ms  [CUDA memset]
#                     0.00%  2.6880us         1  2.6880us  2.6880us  2.6880us  [CUDA memcpy DtoH]
#       API calls:   58.19%  9.72708s     15090  644.60us  3.1000us  7.5263ms  cudaDeviceSynchronize
#                    24.22%  4.04846s     30330  133.48us  13.274us  2.5108ms  cudaMemPrefetchAsync
#                    13.07%  2.18435s     15000  145.62us  15.709us  3.3486ms  cudaLaunchKernel
# ...

# %%
# %%bash
# nvprof ./CUDA_cpso_4_rosenbrock
# Out:
# ==142490== NVPROF is profiling process 142490, command: ./CUDA_cpso_4_rosenbrock
# ==142490== Profiling application: ./CUDA_cpso_4_rosenbrock
# ==142490== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   99.66%  4.68398s     15000  312.27us  77.471us  5.3655ms  particleAction(Swarm*, unsigned long, int, double*, int, int, double (*) (unsigned long, double*, double, unsigned long))
#                     0.34%  16.030ms        30  534.34us  216.03us  953.82us  [CUDA memset]
#                     0.00%  3.9680us         1  3.9680us  3.9680us  3.9680us  [CUDA memcpy DtoH]
#       API calls:   55.95%  8.75649s     15090  580.28us  2.9840us  10.513ms  cudaDeviceSynchronize
#                    24.70%  3.86528s     30330  127.44us  14.229us  5.1572ms  cudaMemPrefetchAsync
#                    10.59%  1.65727s     15000  110.48us  15.468us  2.8276ms  cudaLaunchKernel
# ...

# %%
# %%bash
# nsys profile  -o CUDA_cpso_4_sphere ./CUDA_cpso_4_sphere
# Out:
# WARNING: Device-side CUDA Event completion trace is currently enabled.
#          This may increase runtime overhead and the likelihood of false
#          dependencies across CUDA Streams. If you wish to avoid this, please
#          disable the feature with --cuda-event-trace=false.
# WARNING: CPU IP/backtrace sampling not supported, disabling.
# Try the 'nsys status --environment' command to learn more.
#
# WARNING: CPU context switch tracing not supported, disabling.
# Try the 'nsys status --environment' command to learn more.
#
# Failed to create '/home/jupyter-luis_miguel_b_razo-d01a5/Machine Project/CUDA_cpso_4_sphere.nsys-rep': File exists.
# Use `--force-overwrite true` to overwrite existing files.
# ...
# Generating '/tmp/nsys-report-be63.qdstrm'
# [1/1] [========================100%] nsys-report-7f1b.nsys-rep
# Generated:
# 	/tmp/nsys-report-7f1b.nsys-rep

# %%
# %%bash
# nsys profile  -o CUDA_cpso_4_ackley ./CUDA_cpso_4_ackley
# Out:
# WARNING: Device-side CUDA Event completion trace is currently enabled.
#          This may increase runtime overhead and the likelihood of false
#          dependencies across CUDA Streams. If you wish to avoid this, please
#          disable the feature with --cuda-event-trace=false.
# WARNING: CPU IP/backtrace sampling not supported, disabling.
# Try the 'nsys status --environment' command to learn more.
#
# WARNING: CPU context switch tracing not supported, disabling.
# Try the 'nsys status --environment' command to learn more.
#
# Failed to create '/home/jupyter-luis_miguel_b_razo-d01a5/Machine Project/CUDA_cpso_4_ackley.nsys-rep': File exists.
# Use `--force-overwrite true` to overwrite existing files.
# ...
# Generating '/tmp/nsys-report-1bb1.qdstrm'
# [1/1] [========================100%] nsys-report-7609.nsys-rep
# Generated:
# 	/tmp/nsys-report-7609.nsys-rep

# %%
# %%bash
# nsys profile  -o CUDA_cpso_4_rosenbrock ./CUDA_cpso_4_rosenbrock
# Out:
# WARNING: Device-side CUDA Event completion trace is currently enabled.
#          This may increase runtime overhead and the likelihood of false
#          dependencies across CUDA Streams. If you wish to avoid this, please
#          disable the feature with --cuda-event-trace=false.
# WARNING: CPU IP/backtrace sampling not supported, disabling.
# Try the 'nsys status --environment' command to learn more.
#
# WARNING: CPU context switch tracing not supported, disabling.
# Try the 'nsys status --environment' command to learn more.
#
# Failed to create '/home/jupyter-luis_miguel_b_razo-d01a5/Machine Project/CUDA_cpso_4_rosenbrock.nsys-rep': File exists.
# Use `--force-overwrite true` to overwrite existing files.
# ...
# Generating '/tmp/nsys-report-63ae.qdstrm'
# [1/1] [========================100%] nsys-report-cfbe.nsys-rep
# Generated:
# 	/tmp/nsys-report-cfbe.nsys-rep

# %% [markdown]
# # CUDA Execution - 256 Dimensions

# %%
# %%bash
# nvcc CUDA_cpso_256_sphere.cu -o CUDA_cpso_256_sphere --expt-relaxed-constexpr -arch=sm_70 -Wno-deprecated-gpu-targets

# %%
# %%bash
# nvcc CUDA_cpso_256_ackley.cu -o CUDA_cpso_256_ackley --expt-relaxed-constexpr -arch=sm_70 -Wno-deprecated-gpu-targets

# %%
# %%bash
# nvcc CUDA_cpso_256_rosenbrock.cu -o CUDA_cpso_256_rosenbrock --expt-relaxed-constexpr -arch=sm_70 -Wno-deprecated-gpu-targets

# %%
# %%bash
# nvprof ./CUDA_cpso_256_sphere
# Out:
# ==142997== NVPROF is profiling process 142997, command: ./CUDA_cpso_256_sphere
# ==142997== Profiling application: ./CUDA_cpso_256_sphere
# ==142997== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   99.72%  9.43835s     15000  629.22us  210.98us  19.422ms  particleAction(Swarm*, unsigned long, int, double*, int, int, double (*) (unsigned long, double*, double, unsigned long))
#                     0.28%  26.467ms        30  882.22us  558.20us  1.4956ms  [CUDA memset]
#                     0.00%  3.5200us         1  3.5200us  3.5200us  3.5200us  [CUDA memcpy DtoH]
#       API calls:   63.47%  16.3201s     15090  1.0815ms  4.9480us  20.461ms  cudaDeviceSynchronize
#                    20.47%  5.26196s     45450  115.77us  2.7240us  3.0973ms  cudaMemPrefetchAsync
#                     8.24%  2.11825s     15000  141.22us  18.134us  2.7375ms  cudaLaunchKernel
# ...

# %%
# %%bash
# nvprof ./CUDA_cpso_256_ackley
# Out:
# ==143038== NVPROF is profiling process 143038, command: ./CUDA_cpso_256_ackley
# ==143038== Profiling application: ./CUDA_cpso_256_ackley
# ==143038== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   99.76%  12.3951s     15000  826.34us  292.10us  24.688ms  particleAction(Swarm*, unsigned long, int, double*, int, int, double (*) (unsigned long, double*, double, unsigned long))
#                     0.24%  29.931ms        30  997.71us  552.09us  1.7835ms  [CUDA memset]
#                     0.00%  2.1750us         1  2.1750us  2.1750us  2.1750us  [CUDA memcpy DtoH]
#       API calls:   61.17%  20.5633s     15090  1.3627ms  6.1560us  25.961ms  cudaDeviceSynchronize
#                    23.05%  7.74801s     45450  170.47us  2.5510us  4.7286ms  cudaMemPrefetchAsync
#                     9.95%  3.34411s     15000  222.94us  18.249us  3.2718ms  cudaLaunchKernel
# ...

# %%
# %%bash
# nvprof ./CUDA_cpso_256_rosenbrock
# Out:
# ==143115== NVPROF is profiling process 143115, command: ./CUDA_cpso_256_rosenbrock
# ==143115== Profiling application: ./CUDA_cpso_256_rosenbrock
# ==143115== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   99.73%  10.4101s     15000  694.01us  197.76us  17.899ms  particleAction(Swarm*, unsigned long, int, double*, int, int, double (*) (unsigned long, double*, double, unsigned long))
#                     0.27%  28.069ms        30  935.64us  451.29us  3.7621ms  [CUDA memset]
#                     0.00%  2.3360us         1  2.3360us  2.3360us  2.3360us  [CUDA memcpy DtoH]
#       API calls:   60.40%  17.7025s     15090  1.1731ms  5.7520us  19.040ms  cudaDeviceSynchronize
#                    23.66%  6.93284s     45450  152.54us  3.3500us  7.3086ms  cudaMemPrefetchAsync
#                    10.24%  3.00027s     15000  200.02us  16.434us  3.1046ms  cudaLaunchKernel
# ...

# %%
# %%bash
# nsys profile  -o CUDA_cpso_256_sphere ./CUDA_cpso_256_sphere
# Out:
# WARNING: Device-side CUDA Event completion trace is currently enabled.
#          This may increase runtime overhead and the likelihood of false
#          dependencies across CUDA Streams. If you wish to avoid this, please
#          disable the feature with --cuda-event-trace=false.
# WARNING: CPU IP/backtrace sampling not supported, disabling.
# Try the 'nsys status --environment' command to learn more.
#
# WARNING: CPU context switch tracing not supported, disabling.
# Try the 'nsys status --environment' command to learn more.
# ...
# Generating '/tmp/nsys-report-874c.qdstrm'
# [1/1] [========================100%] CUDA_cpso_256_sphere.nsys-rep
# Generated:
# 	/home/jupyter-luis_miguel_b_razo-d01a5/Machine Project/CUDA_cpso_256_sphere.nsys-rep

# %%
# %%bash
# nsys profile  -o CUDA_cpso_256_ackley ./CUDA_cpso_256_ackley
# Out:
# WARNING: Device-side CUDA Event completion trace is currently enabled.
#          This may increase runtime overhead and the likelihood of false
#          dependencies across CUDA Streams. If you wish to avoid this, please
#          disable the feature with --cuda-event-trace=false.
# WARNING: CPU IP/backtrace sampling not supported, disabling.
# Try the 'nsys status --environment' command to learn more.
#
# WARNING: CPU context switch tracing not supported, disabling.
# Try the 'nsys status --environment' command to learn more.
# ...
# Generating '/tmp/nsys-report-fcfb.qdstrm'
# [1/1] [========================100%] CUDA_cpso_256_ackley.nsys-rep
# Generated:
# 	/home/jupyter-luis_miguel_b_razo-d01a5/Machine Project/CUDA_cpso_256_ackley.nsys-rep

# %%
# %%bash
# nsys profile  -o CUDA_cpso_256_rosenbrock ./CUDA_cpso_256_rosenbrock
# Out:
# WARNING: Device-side CUDA Event completion trace is currently enabled.
#          This may increase runtime overhead and the likelihood of false
#          dependencies across CUDA Streams. If you wish to avoid this, please
#          disable the feature with --cuda-event-trace=false.
# WARNING: CPU IP/backtrace sampling not supported, disabling.
# Try the 'nsys status --environment' command to learn more.
#
# WARNING: CPU context switch tracing not supported, disabling.
# Try the 'nsys status --environment' command to learn more.
# ...
# Generating '/tmp/nsys-report-5b6b.qdstrm'
# [1/1] [========================100%] CUDA_cpso_256_rosenbrock.nsys-rep
# Generated:
# 	/home/jupyter-luis_miguel_b_razo-d01a5/Machine Project/CUDA_cpso_256_rosenbrock.nsys-rep

# %% [markdown]
# # CUDA Execution - 2^10 Dimensions

# %%
# %%bash
# nvcc "CUDA_cpso_2(10)_sphere.cu" -o "CUDA_cpso_2(10)_sphere" --expt-relaxed-constexpr -arch=sm_70 -Wno-deprecated-gpu-targets

# %%
# %%bash
# nvcc "CUDA_cpso_2(10)_ackley.cu" -o "CUDA_cpso_2(10)_ackley" --expt-relaxed-constexpr -arch=sm_70 -Wno-deprecated-gpu-targets

# %%
# %%bash
# nvcc "CUDA_cpso_2(10)_rosenbrock.cu" -o "CUDA_cpso_2(10)_rosenbrock" --expt-relaxed-constexpr -arch=sm_70 -Wno-deprecated-gpu-targets

# %%
# %%bash
# nvprof "./CUDA_cpso_2(10)_sphere"
# Out:
# ==143661== NVPROF is profiling process 143661, command: ./CUDA_cpso_2(10)_sphere
# ==143661== Profiling application: ./CUDA_cpso_2(10)_sphere
# ==143661== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   99.75%  12.5308s     15000  835.39us  358.24us  62.718ms  particleAction(Swarm*, unsigned long, int, double*, int, int, double (*) (unsigned long, double*, double, unsigned long))
#                     0.25%  30.784ms        30  1.0261ms  410.37us  3.2791ms  [CUDA memset]
#                     0.00%  2.7520us         1  2.7520us  2.7520us  2.7520us  [CUDA memcpy DtoH]
#       API calls:   57.57%  19.5769s     15090  1.2973ms  5.3780us  66.358ms  cudaDeviceSynchronize
#                    24.98%  8.49372s     91530  92.797us  2.4620us  6.1021ms  cudaMemPrefetchAsync
#                     6.90%  2.34748s     15000  156.50us  18.322us  2.3928ms  cudaLaunchKernel
# ...

# %%
# %%bash
# nvprof "./CUDA_cpso_2(10)_ackley"
# Out:
# ==143715== NVPROF is profiling process 143715, command: ./CUDA_cpso_2(10)_ackley
# ==143715== Profiling application: ./CUDA_cpso_2(10)_ackley
# ==143715== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   99.89%  28.0770s     15000  1.8718ms  1.2423ms  67.462ms  particleAction(Swarm*, unsigned long, int, double*, int, int, double (*) (unsigned long, double*, double, unsigned long))
#                     0.11%  29.635ms        30  987.84us  511.26us  2.3128ms  [CUDA memset]
#                     0.00%  2.2720us         1  2.2720us  2.2720us  2.2720us  [CUDA memcpy DtoH]
#       API calls:   70.56%  41.0688s     15090  2.7216ms  5.1880us  71.163ms  cudaDeviceSynchronize
#                    18.67%  10.8677s     91530  118.73us  2.7970us  3.5885ms  cudaMemPrefetchAsync
#                     4.81%  2.80009s     15000  186.67us  27.686us  2.1649ms  cudaLaunchKernel
# ...

# %%
# %%bash
# nvprof "./CUDA_cpso_2(10)_rosenbrock"
# Out:
# ==143799== NVPROF is profiling process 143799, command: ./CUDA_cpso_2(10)_rosenbrock
# ==143799== Profiling application: ./CUDA_cpso_2(10)_rosenbrock
# ==143799== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   99.79%  17.4534s     15000  1.1636ms  596.25us  80.773ms  particleAction(Swarm*, unsigned long, int, double*, int, int, double (*) (unsigned long, double*, double, unsigned long))
#                     0.21%  37.252ms        30  1.2417ms  582.01us  4.9486ms  [CUDA memset]
#                     0.00%  2.2080us         1  2.2080us  2.2080us  2.2080us  [CUDA memcpy DtoH]
#       API calls:   61.82%  27.1320s     15090  1.7980ms  4.7600us  82.114ms  cudaDeviceSynchronize
#                    23.36%  10.2535s     91530  112.02us  2.9170us  5.7526ms  cudaMemPrefetchAsync
#                     5.65%  2.47821s     15000  165.21us  22.806us  4.6763ms  cudaLaunchKernel
# ...

# %%
# %%bash
# nsys profile  -o "CUDA_cpso_2(10)_sphere.cu" "./CUDA_cpso_2(10)_sphere"
# Out:
# WARNING: Device-side CUDA Event completion trace is currently enabled.
#          This may increase runtime overhead and the likelihood of false
#          dependencies across CUDA Streams. If you wish to avoid this, please
#          disable the feature with --cuda-event-trace=false.
# WARNING: CPU IP/backtrace sampling not supported, disabling.
# Try the 'nsys status --environment' command to learn more.
#
# WARNING: CPU context switch tracing not supported, disabling.
# Try the 'nsys status --environment' command to learn more.
# ...
# Generating '/tmp/nsys-report-be57.qdstrm'
# [1/1] [========================100%] CUDA_cpso_2(10)_sphere.cu.nsys-rep
# Generated:
# 	/home/jupyter-luis_miguel_b_razo-d01a5/Machine Project/CUDA_cpso_2(10)_sphere.cu.nsys-rep

# %%
# %%bash
# nsys profile  -o "CUDA_cpso_2(10)_ackley.cu" "./CUDA_cpso_2(10)_ackley"
# Out:
# WARNING: Device-side CUDA Event completion trace is currently enabled.
#          This may increase runtime overhead and the likelihood of false
#          dependencies across CUDA Streams. If you wish to avoid this, please
#          disable the feature with --cuda-event-trace=false.
# WARNING: CPU IP/backtrace sampling not supported, disabling.
# Try the 'nsys status --environment' command to learn more.
#
# WARNING: CPU context switch tracing not supported, disabling.
# Try the 'nsys status --environment' command to learn more.
# ...
# Generating '/tmp/nsys-report-4ca8.qdstrm'
# [1/1] [========================100%] CUDA_cpso_2(10)_ackley.cu.nsys-rep
# Generated:
# 	/home/jupyter-luis_miguel_b_razo-d01a5/Machine Project/CUDA_cpso_2(10)_ackley.cu.nsys-rep

# %%
# %%bash
# nsys profile  -o "CUDA_cpso_2(10)_rosenbrock.cu" "./CUDA_cpso_2(10)_rosenbrock"
# Out:
# WARNING: Device-side CUDA Event completion trace is currently enabled.
#          This may increase runtime overhead and the likelihood of false
#          dependencies across CUDA Streams. If you wish to avoid this, please
#          disable the feature with --cuda-event-trace=false.
# WARNING: CPU IP/backtrace sampling not supported, disabling.
# Try the 'nsys status --environment' command to learn more.
#
# WARNING: CPU context switch tracing not supported, disabling.
# Try the 'nsys status --environment' command to learn more.
# ...
# Generating '/tmp/nsys-report-fc0e.qdstrm'
# [1/1] [========================100%] CUDA_cpso_2(10)_rosenbrock.cu.nsys-rep
# Generated:
# 	/home/jupyter-luis_miguel_b_razo-d01a5/Machine Project/CUDA_cpso_2(10)_rosenbrock.cu.nsys-rep

# %% [markdown]
# # CUDA Execution - 2^13 Dimensions

# %%
# %%bash
# nvcc "CUDA_cpso_2(13)_sphere.cu" -o "CUDA_cpso_2(13)_sphere" --expt-relaxed-constexpr -arch=sm_70 -Wno-deprecated-gpu-targets

# %%
# %%bash
# nvcc "CUDA_cpso_2(13)_ackley.cu" -o "CUDA_cpso_2(13)_ackley" --expt-relaxed-constexpr -arch=sm_70 -Wno-deprecated-gpu-targets

# %%
# %%bash
# nvcc "CUDA_cpso_2(13)_rosenbrock.cu" -o "CUDA_cpso_2(13)_rosenbrock" --expt-relaxed-constexpr -arch=sm_70 -Wno-deprecated-gpu-targets

# %%
# %%bash
# nvprof "./CUDA_cpso_2(13)_sphere"
# Out:
# ==144459== NVPROF is profiling process 144459, command: ./CUDA_cpso_2(13)_sphere
# ==144459== Profiling application: ./CUDA_cpso_2(13)_sphere
# ==144459== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   99.97%  145.477s     15000  9.6985ms  7.8953ms  579.82ms  particleAction(Swarm*, unsigned long, int, double*, int, int, double (*) (unsigned long, double*, double, unsigned long))
#                     0.03%  39.936ms        30  1.3312ms  586.75us  2.5010ms  [CUDA memset]
#                     0.00%  2.5600us         1  2.5600us  2.5600us  2.5600us  [CUDA memcpy DtoH]
#       API calls:   71.26%  163.433s     15090  10.831ms  9.1110us  581.03ms  cudaDeviceSynchronize
#                    16.69%  38.2666s    521610  73.362us  2.7380us  10.899ms  cudaMemPrefetchAsync
#                     6.70%  15.3674s    245820  62.514us  16.959us  23.293ms  cudaFree
# ...

# %%
# %%bash
# nvprof "./CUDA_cpso_2(13)_ackley"
# Out:
# ==144728== NVPROF is profiling process 144728, command: ./CUDA_cpso_2(13)_ackley
# ==144728== Profiling application: ./CUDA_cpso_2(13)_ackley
# ==144728== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   99.99%  924.891s     15000  61.659ms  59.087ms  612.19ms  particleAction(Swarm*, unsigned long, int, double*, int, int, double (*) (unsigned long, double*, double, unsigned long))
#                     0.01%  46.973ms        30  1.5658ms  703.52us  6.9268ms  [CUDA memset]
#                     0.00%  2.8800us         1  2.8800us  2.8800us  2.8800us  [CUDA memcpy DtoH]
#       API calls:   92.66%  948.580s     15090  62.861ms  17.886us  613.94ms  cudaDeviceSynchronize
#                     4.17%  42.6621s    521610  81.789us  2.8630us  8.8333ms  cudaMemPrefetchAsync
#                     1.74%  17.8167s    245820  72.478us  17.623us  31.498ms  cudaFree
# ...

# %%
# %%bash
# nvprof "./CUDA_cpso_2(13)_rosenbrock"
# Out:
# ==145549== NVPROF is profiling process 145549, command: ./CUDA_cpso_2(13)_rosenbrock
# ==145549== Profiling application: ./CUDA_cpso_2(13)_rosenbrock
# ==145549== Profiling result:
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#  GPU activities:   99.99%  359.425s     15000  23.962ms  21.335ms  735.93ms  particleAction(Swarm*, unsigned long, int, double*, int, int, double (*) (unsigned long, double*, double, unsigned long))
#                     0.01%  48.360ms        30  1.6120ms  852.35us  4.2852ms  [CUDA memset]
#                     0.00%  3.5200us         1  3.5200us  3.5200us  3.5200us  [CUDA memcpy DtoH]
#       API calls:   82.46%  385.006s     15090  25.514ms  22.804us  736.23ms  cudaDeviceSynchronize
#                    10.21%  47.6683s    521610  91.386us  3.0800us  10.594ms  cudaMemPrefetchAsync
#                     3.99%  18.6471s    245820  75.856us  17.753us  30.980ms  cudaFree
# ...

# %%
# %%bash
# nsys profile  -o "CUDA_cpso_2(13)_sphere.cu" "./CUDA_cpso_2(13)_sphere"
# Out:
# WARNING: Device-side CUDA Event completion trace is currently enabled.
#          This may increase runtime overhead and the likelihood of false
#          dependencies across CUDA Streams. If you wish to avoid this, please
#          disable the feature with --cuda-event-trace=false.
# WARNING: CPU IP/backtrace sampling not supported, disabling.
# Try the 'nsys status --environment' command to learn more.
#
# WARNING: CPU context switch tracing not supported, disabling.
# Try the 'nsys status --environment' command to learn more.
# ...
# Generating '/tmp/nsys-report-0a82.qdstrm'
# [1/1] [========================100%] CUDA_cpso_2(13)_sphere.cu.nsys-rep
# Generated:
# 	/home/jupyter-luis_miguel_b_razo-d01a5/Machine Project/CUDA_cpso_2(13)_sphere.cu.nsys-rep

# %%
# %%bash
# nsys profile  -o "CUDA_cpso_2(13)_ackley.cu" "./CUDA_cpso_2(13)_ackley"
# Out:
# WARNING: Device-side CUDA Event completion trace is currently enabled.
#          This may increase runtime overhead and the likelihood of false
#          dependencies across CUDA Streams. If you wish to avoid this, please
#          disable the feature with --cuda-event-trace=false.
# WARNING: CPU IP/backtrace sampling not supported, disabling.
# Try the 'nsys status --environment' command to learn more.
#
# WARNING: CPU context switch tracing not supported, disabling.
# Try the 'nsys status --environment' command to learn more.
# ...
# Generating '/tmp/nsys-report-3082.qdstrm'
# [1/1] [========================100%] CUDA_cpso_2(13)_ackley.cu.nsys-rep
# Generated:
# 	/home/jupyter-luis_miguel_b_razo-d01a5/Machine Project/CUDA_cpso_2(13)_ackley.cu.nsys-rep

# %%
# %%bash
# nsys profile  -o "CUDA_cpso_2(13)_rosenbrock.cu" "./CUDA_cpso_2(13)_rosenbrock"
# Out:
# WARNING: Device-side CUDA Event completion trace is currently enabled.
#          This may increase runtime overhead and the likelihood of false
#          dependencies across CUDA Streams. If you wish to avoid this, please
#          disable the feature with --cuda-event-trace=false.
# WARNING: CPU IP/backtrace sampling not supported, disabling.
# Try the 'nsys status --environment' command to learn more.
#
# WARNING: CPU context switch tracing not supported, disabling.
# Try the 'nsys status --environment' command to learn more.
# ...
# Generating '/tmp/nsys-report-ad71.qdstrm'
# [1/1] [========================100%] CUDA_cpso_2(13)_rosenbrock.cu.nsys-rep
# Generated:
# 	/home/jupyter-luis_miguel_b_razo-d01a5/Machine Project/CUDA_cpso_2(13)_rosenbrock.cu.nsys-rep

# %% [markdown]
# # CUDA Execution - 2^15 Dimensions

# %%
# %%bash
# nvcc "CUDA_cpso_2(15)_sphere.cu" -o "CUDA_cpso_2(15)_sphere" --expt-relaxed-constexpr -arch=sm_70 -Wno-deprecated-gpu-targets

# %%
# %%bash
# nvcc "CUDA_cpso_2(15)_ackley.cu" -o "CUDA_cpso_2(15)_ackley" --expt-relaxed-constexpr -arch=sm_70 -Wno-deprecated-gpu-targets

# %%
# %%bash
# nvcc "CUDA_cpso_2(15)_rosenbrock.cu" -o "CUDA_cpso_2(15)_rosenbrock" --expt-relaxed-constexpr -arch=sm_70 -Wno-deprecated-gpu-targets

# %%
# %%bash
# nvprof "./CUDA_cpso_2(15)_sphere"
# Out:
# ==148623== NVPROF is profiling process 148623, command: ./CUDA_cpso_2(15)_sphere
# ==148623== Profiling application: ./CUDA_cpso_2(15)_sphere
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[43], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', 'nvprof "./CUDA_cpso_2(15)_sphere"\n')
#
# File /opt/tljh/user/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2547, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2546     args = (magic_arg_s, cell)
# -> 2547     result = fn(*args, **kwargs)
#    2549 # The code below prevents the output from being displayed
#    2550 # when using magics with decorator @output_can_be_silenced
#    2551 # when the last Python token in the expression is a ';'.
#
# ...

# %%
# %%bash
# nvprof "./CUDA_cpso_2(15)_ackley"

# %%
# %%bash
# nvprof "./CUDA_cpso_2(15)_rosenbrock"

# %%
# %%bash
# nsys profile  -o "CUDA_cpso_2(15)_sphere.cu" "./CUDA_cpso_2(15)_sphere"

# %%
# %%bash
# nsys profile  -o "CUDA_cpso_2(15)_ackley.cu" "./CUDA_cpso_2(15)_ackley"

# %%
# %%bash
# nsys profile  -o "CUDA_cpso_2(15)_rosenbrock.cu" "./CUDA_cpso_2(15)_rosenbrock"

# %% [markdown]
# # C Execution

# %%
# %%bash
# gcc C_CPSO.c -o C_CPSO -lm

# %%
# %%bash
# ./C_CPSO
# Out:
# Rosenbrock at (0, 0, 0, 0) = 3.000000
# Rosenbrock at (1,1,1,1) (minima) = 0.000000
# Sphere at (0, 0, 0, 0) (minima) = 0.000000
# Sphere at (1,1,1,1) = 4.000000
# Ackley at (0, 0, 0, 0) (minima) = 0.000000
# Ackley at (1,1,1,1) = 3.625385
# Function (in C) average time for 30 loops is 28.167567 milliseconds to execute function 0 at 4 dimensions
# Function (in C) average time for 30 loops is 28049.122633 milliseconds to execute function 0 at 256 dimensions
# Function (in C) average time for 30 loops is 425413.873600 milliseconds to execute function 0 at 1024 dimensions
# Function (in C) average time for 30 loops is 53.620133 milliseconds to execute function 1 at 4 dimensions
# Function (in C) average time for 30 loops is 102780.529933 milliseconds to execute function 1 at 256 dimensions
# Function (in C) average time for 30 loops is 1411231.990400 milliseconds to execute function 1 at 1024 dimensions
# ...
